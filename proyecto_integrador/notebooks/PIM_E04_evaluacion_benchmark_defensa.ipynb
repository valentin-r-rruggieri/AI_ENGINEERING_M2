# %% [markdown]
# # Laboratorio 4 — Evaluación, benchmark y defensa
#
# **Proyecto integrador AEM2 — RAG FAQ de RR.HH.**
#
# ## Problema
#
# Un proyecto no está terminado cuando contesta una demo: debe demostrar retrieval, contrato, errores previsibles y decisiones comparables entre Chroma y FAISS.

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación PI, modularidad y resiliencia; Excalidraw PI, rúbrica, errores y estructura del repositorio.
#
# Este laboratorio usa el código modular del proyecto; el diagrama se recrea en código y no depende de capturas.

# %% [markdown]
# ## Objetivos
#
# - Relacionar una decisión de arquitectura con un archivo del proyecto.
# - Observar entradas, salidas y validaciones.
# - Ejecutar una práctica local sin necesidad de una clave.
# - Identificar qué parte requiere API y qué error se debe mostrar.

# %% [markdown]
# ## Modelo mental
#
# Separá calidad de retrieval, grounding, contrato y rendimiento. Una defensa sólida muestra evidencia, una limitación real y un próximo experimento.

# %%
import matplotlib.pyplot as plt
metrics={"Recall@4":.86,"grounding":.82,"schema":1.0,"p95 objetivo":.75}
plt.bar(metrics.keys(),metrics.values(),color="#6a4c93");plt.ylim(0,1.05);plt.title("Tablero mínimo de aceptación");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# Elegí una métrica que pueda fallar aunque la demo parezca correcta.
#
# ## Práctica guiada
#
# Leé el resultado esperado antes de ejecutar. Después modificá un parámetro y registrá el efecto.

# %%
report=[{"backend":"faiss","recall_at_4":.86,"p95_ms":5},{"backend":"chroma","recall_at_4":.86,"p95_ms":7}]
for row in report: print(row)
errors={"índice ausente":"reindexar","pregunta vacía":"validar","sin evidencia":"abstener"}
print(errors)

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar procedencia, validaciones y una responsabilidad por función. Las llamadas a OpenAI se ejecutan solo tras definir `OPENAI_API_KEY`.

# %% [markdown]
# ## Errores frecuentes
#
# Presentar un único caso feliz; comparar backends con corpus o configuración distintos.

# %% [markdown]
# ## Mini desafío
#
# Prepará una defensa con una pregunta factual, una de procedimiento y una sin evidencia.

# %% [markdown]
# ## Cierre y defensa
#
# Podés ejecutar `python -m unittest discover -s tests -v` y luego los comandos documentados en el README.
#
# Prepará una explicación de 60 segundos: problema, decisión, evidencia y limitación.
