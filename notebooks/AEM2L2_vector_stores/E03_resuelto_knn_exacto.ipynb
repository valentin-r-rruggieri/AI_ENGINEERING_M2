# %% [markdown]
# # k-NN exacto como baseline
#
# **Tipo:** Resuelto · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# Comparar contra todos antes de aproximar

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, sección k-NN exacto vs ANN; Excalidraw L2, trade-off central.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# La búsqueda exacta compara la consulta con cada vector. Es más lenta a escala, pero ofrece la referencia para medir recall de ANN.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
import numpy as np
scores=np.array([.34,.91,.72,.18])
print("Top-3 exacto:",np.argsort(scores)[::-1][:3].tolist())

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿por qué un baseline exacto es útil aunque no sea el índice final?

# %% [markdown]
# ## Práctica guiada
#
# Ordená todos los documentos y verificá sus IDs antes de aplicar optimizaciones.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Usar ANN sin comparar recall contra una referencia exacta.

# %% [markdown]
# ## Mini desafío
#
# E04 persiste este baseline con FAISS Flat.

# %% [markdown]
# ## Cierre
#
# import matplotlib.pyplot as plt
# sizes=[100,1000,10000,100000]
# cost=[n/100 for n in sizes]
# plt.plot(sizes,cost,marker="o");plt.xscale("log");plt.xlabel("vectores");plt.ylabel("trabajo relativo");plt.title("k-NN exacto crece con el corpus");plt.grid(alpha=.3);plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
