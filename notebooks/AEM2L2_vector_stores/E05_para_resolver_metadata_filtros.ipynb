# %% [markdown]
# # Filtros de metadata
#
# **Tipo:** Para resolver · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# Relevancia con restricciones

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, filtro previo de metadata; Excalidraw L2, lectura de consulta.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# La similitud semántica no reemplaza reglas de autorización o dominio. Recuperá candidatos y aplicá filtros coherentes con la política de acceso.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
results=[{"id":"a","score":.92,"department":"rrhh"},{"id":"b","score":.89,"department":"finanzas"},{"id":"c","score":.81,"department":"rrhh"}]
print([row for row in results if row["department"]=="rrhh"])

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿un chunk muy similar pero de otro departamento debe llegar al LLM?

# %% [markdown]
# ## Práctica guiada
#
# Filtrá resultados por departamento y explicá en qué capa colocarías la regla.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Filtrar después de construir el prompt; usar metadata sin tipado ni validación.

# %% [markdown]
# ## Mini desafío
#
# E06 evalúa si esos filtros mantienen recall.

# %% [markdown]
# ## Cierre
#
# import matplotlib.pyplot as plt
# labels=["RRHH","Finanzas","Tecnología"]; values=[5,3,4]
# plt.bar(labels,values,color=["#2a9d8f","#e76f51","#457b9d"]);plt.title("Candidatos por metadata");plt.ylabel("chunks");plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
