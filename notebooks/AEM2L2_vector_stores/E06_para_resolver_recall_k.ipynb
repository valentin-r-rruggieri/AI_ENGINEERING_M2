# %% [markdown]
# # Recall@K para ANN
#
# **Tipo:** Para resolver · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# Velocidad con evidencia de calidad

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, benchmark correcto; Excalidraw L2, kNN vs ANN.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# ANN reduce búsqueda, pero puede omitir vecinos. Recall@K compara sus resultados con el top exacto en las mismas consultas.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
exact={"a","b","c","d","e"};ann={"a","b","e","f","g"}
print("Recall@5:",len(exact&ann)/len(exact))

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿qué parámetro mejorarías si recall es bajo y latencia permite más trabajo?

# %% [markdown]
# ## Práctica guiada
#
# Calculá intersección entre top exacto y top ANN; separá recall de latencia.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Cambiar nprobe o efSearch sin registrar el experimento.

# %% [markdown]
# ## Mini desafío
#
# E07 permite auditar manualmente un ranking pequeño.

# %% [markdown]
# ## Cierre
#
# import matplotlib.pyplot as plt
# settings=[1,4,8,16];recall=[.61,.79,.88,.94];latency=[2,3,5,9]
# fig,ax=plt.subplots(figsize=(6,4));ax.plot(settings,recall,"o-",label="Recall@5");ax.set_ylim(0,1);ax.set_xlabel("esfuerzo de búsqueda")
# ax2=ax.twinx();ax2.plot(settings,latency,"s-",color="peru",label="latencia");ax2.set_ylabel("ms");ax.legend(loc="lower right");plt.title("Trade-off ANN");plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
