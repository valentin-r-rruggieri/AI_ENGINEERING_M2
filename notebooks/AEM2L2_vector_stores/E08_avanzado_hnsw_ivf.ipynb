# %% [markdown]
# # HNSW e IVF
#
# **Tipo:** Avanzado · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# Dos formas de evitar la búsqueda exhaustiva

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, HNSW e IVF; Excalidraw L2, grafo y listas invertidas.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# HNSW navega un grafo de proximidad; IVF selecciona listas candidatas. Ambos intercambian memoria, tiempo de construcción y recall.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
choices={"HNSW":{"memory":"alta","tuning":"efSearch"},"IVF":{"partitions":"nlist","tuning":"nprobe"}}
print(choices)

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿qué estructura elegirías si priorizás actualizaciones y cuál si organizás particiones explícitas?

# %% [markdown]
# ## Práctica guiada
#
# Visualizá candidatos explorados y explicá qué significan efSearch y nprobe.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Copiar parámetros de internet sin medir corpus, hardware ni recall.

# %% [markdown]
# ## Mini desafío
#
# E09 formaliza la comparación con percentiles de latencia.

# %% [markdown]
# ## Cierre
#
# import matplotlib.pyplot as plt
# fig,axes=plt.subplots(1,2,figsize=(8,3))
# axes[0].plot([0,1,2,1.5,2.5],[0,1,.2,2,1.5],"o-");axes[0].set_title("HNSW: navegar vecinos")
# axes[1].bar(["lista 1","lista 2","lista 3"],[8,2,7],color=["#ccc","#f4a261","#ccc"]);axes[1].set_title("IVF: explorar candidatas")
# for ax in axes:ax.grid(alpha=.2)
# plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
