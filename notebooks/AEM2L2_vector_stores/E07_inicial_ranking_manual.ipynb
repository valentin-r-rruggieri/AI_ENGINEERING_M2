# %% [markdown]
# # Warm-up: auditar un ranking
#
# **Tipo:** Inicial · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# Los scores necesitan contexto

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, métricas; Excalidraw L2, IDs y scores en flujo de lectura.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# Un ranking correcto indica métrica, normalización, orden y contenido asociado. Mirar solo un número no alcanza para validar relevancia.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
rows=[("faq-2",.87),("faq-7",.78),("faq-9",.22)]
for item in sorted(rows,key=lambda x:x[1],reverse=True):print(item)

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿qué resultado inspeccionarías primero si la consulta es sobre licencias?

# %% [markdown]
# ## Práctica guiada
#
# Ordená la tabla y agregá una explicación humana para el primer resultado.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Ignorar empates, valores inválidos o dirección de la métrica.

# %% [markdown]
# ## Mini desafío
#
# E08 sustituye la comparación exhaustiva por índices ANN.

# %% [markdown]
# ## Cierre
#
# import matplotlib.pyplot as plt
# scores={"licencias":.87,"vacaciones":.78,"facturación":.22}
# plt.barh(list(scores),list(scores.values()),color="#457b9d");plt.xlim(0,1);plt.title("Auditoría de ranking");plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
