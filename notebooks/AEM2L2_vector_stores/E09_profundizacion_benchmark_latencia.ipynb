# %% [markdown]
# # Benchmark de latencia
#
# **Tipo:** Profundización · **Lecture:** AEM2L2 — Bases de datos vectoriales
#
# ## Problema real
#
# p50 y p95, no solo promedios

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L2, validación y producción; Excalidraw L2, checklist de benchmark.
#
# El diagrama se recrea en código para que puedas modificarlo y razonar sobre sus parámetros.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el trade-off de infraestructura.
# - Formular una predicción verificable.
# - Medir ranking, recall o latencia.
# - Registrar una decisión técnica reproducible.

# %% [markdown]
# ## Modelo mental
#
# El benchmark repite consultas sobre el mismo corpus, registra configuración y reporta calidad junto con percentiles de latencia.
#
# **Pregunta guía:** ¿qué variable controla calidad y cuál controla costo o latencia?

# %%
latency=[3,4,3,5,4,4,5,18,4,3]
print({"p50":float(np.percentile(latency,50)),"p95":float(np.percentile(latency,95))})

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿por qué un promedio bajo puede esconder una mala experiencia?

# %% [markdown]
# ## Práctica guiada
#
# Calculá percentiles sobre muestras de latencia y compará configuraciones sin cambiar los datos.

# %% [markdown]
# ## Resultado esperado
#
# La salida debe conservar IDs, sentido del score y configuración. Una métrica sin su contexto no es evidencia suficiente.

# %% [markdown]
# ## Errores frecuentes
#
# Medir una sola consulta; no anotar versión de índice o modelo.

# %% [markdown]
# ## Mini desafío
#
# E10 compara dos implementaciones bajo el mismo contrato.

# %% [markdown]
# ## Cierre
#
# import numpy as np, matplotlib.pyplot as plt
# latency=np.array([3,4,3,5,4,4,5,18,4,3])
# plt.hist(latency,bins=6,color="#457b9d");plt.title("Distribución de latencia");plt.xlabel("ms");plt.show()
#
# Documentá la hipótesis, la configuración y una métrica antes de pasar al siguiente notebook.
