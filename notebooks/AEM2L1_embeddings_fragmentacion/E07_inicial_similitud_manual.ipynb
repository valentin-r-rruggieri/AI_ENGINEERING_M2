# %% [markdown]
# # Warm-up: ranking manual
#
# **Tipo:** Inicial · **Lecture:** AEM2L1 — Embeddings y fragmentación
#
# ## Problema real
#
# Ordenar antes de automatizar

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L1, similitud; Excalidraw L1, métrica y Top-K.
#
# Este notebook recrea el modelo mental como código reproducible; no incorpora imágenes externas.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el concepto con tus palabras.
# - Anticipar qué debería ocurrir antes de ejecutar el código.
# - Implementar una versión pequeña y verificar su resultado.
# - Relacionar la decisión con calidad, costo o trazabilidad en RAG.

# %% [markdown]
# ## Modelo mental
#
# Antes de usar una base vectorial, conviene poder inspeccionar un ranking pequeño. Eso permite detectar una métrica invertida o una normalización inconsistente.
#
# **Pregunta guía:** ¿qué decisión de ingeniería cambia el resultado y cómo la medirías?

# %%
import numpy as np, matplotlib.pyplot as plt
labels=["contraseña","vacaciones","facturación"]
scores=[.93,.33,.18]
plt.barh(labels,scores,color="#4c78a8"); plt.xlim(0,1); plt.title("Ranking manual de una consulta"); plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿cuál debe ser el primer resultado y por qué?
#
# Escribí una hipótesis breve. Luego contrastala con el resultado visual y numérico.

# %% [markdown]
# ## Práctica guiada
#
# Calculá coseno de forma explícita. La interpretación es tan importante como el número.

# %%
query=np.array([1.,0.,1.])
docs={"contraseña":np.array([.9,0.,.8]),"vacaciones":np.array([0.,1.,.2])}
for name,vector in docs.items():
    score=np.dot(query,vector)/(np.linalg.norm(query)*np.linalg.norm(vector))
    print(name,round(float(score),3))

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe ser legible, trazable y consistente con la hipótesis. Si no lo es, inspeccioná entradas, normalización, unidades y el sentido del score.

# %% [markdown]
# ## Errores frecuentes
#
# Tratar un score absoluto como universal; olvidar que cada modelo tiene una escala propia.

# %% [markdown]
# ## Mini desafío
#
# Agregá un documento irrelevante y verificá que no supere a la evidencia correcta.

# %% [markdown]
# ## Cierre
#
# E08 transforma esta inspección manual en evaluación sistemática.
#
# **Evidencia de aprendizaje:** guardá tu hipótesis, el resultado y una decisión justificada.
