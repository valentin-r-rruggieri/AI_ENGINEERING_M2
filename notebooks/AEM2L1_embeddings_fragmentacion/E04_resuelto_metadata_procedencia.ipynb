# %% [markdown]
# # Overlap y procedencia
#
# **Tipo:** Resuelto · **Lecture:** AEM2L1 — Embeddings y fragmentación
#
# ## Problema real
#
# Evitar que la evidencia se pierda en los bordes

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L1, lámina 'Anatomía de un Chunk: El poder del Overlap'; Excalidraw L1, bloques de chunking y recuperación.
#
# Este notebook recrea el modelo mental como código reproducible; no incorpora imágenes externas.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el concepto con tus palabras.
# - Anticipar qué debería ocurrir antes de ejecutar el código.
# - Implementar una versión pequeña y verificar su resultado.
# - Relacionar la decisión con calidad, costo o trazabilidad en RAG.

# %% [markdown]
# ## Modelo mental
#
# El overlap repite una franja controlada. La metadata permite explicar de qué documento y posición salió cada chunk recuperado.
#
# **Pregunta guía:** ¿qué decisión de ingeniería cambia el resultado y cómo la medirías?

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(9,2.2))
ax.broken_barh([(0,7),(4,7)], (4,4), facecolors=["#9ecae1","#fdae6b"])
ax.text(1,6,"chunk 1",ha="center"); ax.text(9,6,"chunk 2",ha="center")
ax.axvspan(4,7,color="#d9ef8b",alpha=.7); ax.text(5.5,3,"overlap",ha="center")
ax.set(xlim=(0,12), ylim=(0,10), yticks=[], xlabel="posición en el documento", title="La zona verde aparece en ambos chunks")
plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿qué palabras aparecen en ambos chunks cuando el overlap vale 3?
#
# Escribí una hipótesis breve. Luego contrastala con el resultado visual y numérico.

# %% [markdown]
# ## Práctica guiada
#
# El gráfico colorea la región duplicada; la duplicación tiene costo, pero puede impedir que una regla quede aislada.

# %%
def chunks_with_overlap(words, size=7, overlap=3):
    return [" ".join(words[i:i+size]) for i in range(0, len(words), size-overlap)]
sample = "La política de vacaciones requiere aprobación del líder antes de confirmar".split()
print(chunks_with_overlap(sample))

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe ser legible, trazable y consistente con la hipótesis. Si no lo es, inspeccioná entradas, normalización, unidades y el sentido del score.

# %% [markdown]
# ## Errores frecuentes
#
# Usar overlap enorme por defecto; omitir source, chunk_id o posición de origen.

# %% [markdown]
# ## Mini desafío
#
# Generá chunks con otro overlap y medí cuántas palabras repetidas agregaste.

# %% [markdown]
# ## Cierre
#
# E05 convierte esos chunks en registros recuperables.
#
# **Evidencia de aprendizaje:** guardá tu hipótesis, el resultado y una decisión justificada.
