# %% [markdown]
# # Elegir chunk_size con evidencia
#
# **Tipo:** Para resolver · **Lecture:** AEM2L1 — Embeddings y fragmentación
#
# ## Problema real
#
# No existe un tamaño universal

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L1, pipeline de chunks; presentación L1, trade-off de contexto y costo.
#
# Este notebook recrea el modelo mental como código reproducible; no incorpora imágenes externas.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el concepto con tus palabras.
# - Anticipar qué debería ocurrir antes de ejecutar el código.
# - Implementar una versión pequeña y verificar su resultado.
# - Relacionar la decisión con calidad, costo o trazabilidad en RAG.

# %% [markdown]
# ## Modelo mental
#
# El tamaño del chunk es una hipótesis. Debe contrastarse con consultas reales, recall, costo y legibilidad del contexto recuperado.
#
# **Pregunta guía:** ¿qué decisión de ingeniería cambia el resultado y cómo la medirías?

# %%
import matplotlib.pyplot as plt
sizes, recall, context = [80,160,320], [.72,.86,.81], [1.2,2.1,4.0]
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(sizes, recall, marker="o", label="Recall@K")
ax.set(xlabel="palabras por chunk", ylabel="Recall@K", ylim=(0,1), title="Hipótesis de chunk_size")
ax2=ax.twinx(); ax2.plot(sizes, context, marker="s", color="peru", label="contexto")
ax2.set_ylabel("contexto enviado (unidades relativas)"); plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿cuál configuración puede recuperar mejor una instrucción corta y cuál puede conservar mejor un procedimiento largo?
#
# Escribí una hipótesis breve. Luego contrastala con el resultado visual y numérico.

# %% [markdown]
# ## Práctica guiada
#
# Compará configuraciones sobre el mismo documento; no cambies tamaño, modelo y métrica al mismo tiempo.

# %%
experiments = [{"size":80,"overlap":12,"recall":.72},{"size":160,"overlap":24,"recall":.86},{"size":320,"overlap":48,"recall":.81}]
best=max(experiments,key=lambda row:row["recall"])
print("Configuración candidata:", best)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe ser legible, trazable y consistente con la hipótesis. Si no lo es, inspeccioná entradas, normalización, unidades y el sentido del score.

# %% [markdown]
# ## Errores frecuentes
#
# Elegir 1000 tokens solo porque parece estándar; optimizar sin un golden set.

# %% [markdown]
# ## Mini desafío
#
# Completá una tabla de decisión con tres tamaños y defendé uno para el FAQ de RR.HH.

# %% [markdown]
# ## Cierre
#
# E06 conecta el tamaño elegido con una generación de embeddings reproducible.
#
# **Evidencia de aprendizaje:** guardá tu hipótesis, el resultado y una decisión justificada.
