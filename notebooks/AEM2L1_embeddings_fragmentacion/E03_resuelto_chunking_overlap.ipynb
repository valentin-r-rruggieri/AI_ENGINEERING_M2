# %% [markdown]
# # Chunking con sentido
#
# **Tipo:** Resuelto · **Lecture:** AEM2L1 — Embeddings y fragmentación
#
# ## Problema real
#
# Un documento entero diluye la evidencia

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Presentación L1, sección de fragmentación; Excalidraw L1, flujo 'Docs originales → Chunks → Embeddings'.
#
# Este notebook recrea el modelo mental como código reproducible; no incorpora imágenes externas.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar el concepto con tus palabras.
# - Anticipar qué debería ocurrir antes de ejecutar el código.
# - Implementar una versión pequeña y verificar su resultado.
# - Relacionar la decisión con calidad, costo o trazabilidad en RAG.

# %% [markdown]
# ## Modelo mental
#
# Fragmentar no es cortar al azar: cada chunk debe poder responder una parte coherente de una consulta y conservar contexto suficiente.
#
# **Pregunta guía:** ¿qué decisión de ingeniería cambia el resultado y cómo la medirías?

# %%
import matplotlib.pyplot as plt
words = "Para recuperar la contraseña elegí olvidé mi contraseña y revisá tu correo laboral".split()
fig, ax = plt.subplots(figsize=(9,2))
for i, word in enumerate(words):
    ax.text(i, 0, word, ha="center", va="center", bbox={"boxstyle":"round","fc":"#e8eef7"})
ax.axvspan(-.5, 4.5, color="#f0b27a", alpha=.35, label="chunk 1")
ax.axvspan(4.5, len(words)-.5, color="#85c1e9", alpha=.35, label="chunk 2")
ax.set(xlim=(-1,len(words)), ylim=(-1,1), yticks=[], title="Un corte debe preservar una unidad de sentido"); ax.legend(); plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# Predicción: ¿qué falla si una instrucción queda dividida justo entre dos chunks?
#
# Escribí una hipótesis breve. Luego contrastala con el resultado visual y numérico.

# %% [markdown]
# ## Práctica guiada
#
# Observá dónde termina cada fragmento y compará la respuesta con y sin un corte que respete palabras.

# %%
def split_words(text, size):
    words = text.split()
    return [" ".join(words[i:i+size]) for i in range(0, len(words), size)]
print(split_words(" ".join(words), 5))

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe ser legible, trazable y consistente con la hipótesis. Si no lo es, inspeccioná entradas, normalización, unidades y el sentido del score.

# %% [markdown]
# ## Errores frecuentes
#
# Cortar por caracteres sin revisar palabras; enviar un manual completo como un único embedding.

# %% [markdown]
# ## Mini desafío
#
# Probá chunk_size=5 y luego 10: anotá qué información se vuelve demasiado amplia o demasiado incompleta.

# %% [markdown]
# ## Cierre
#
# E04 muestra cómo el overlap protege el límite entre fragmentos.
#
# **Evidencia de aprendizaje:** guardá tu hipótesis, el resultado y una decisión justificada.
