# %% [markdown]
# # Calidad semántica con golden cases
#
# **Tipo:** Resuelto · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# La dimensión no garantiza relevancia

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, arquitectura bi-encoder; lecture L4, calidad semántica.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# La calidad se mide con preguntas y evidencias reales. Un modelo más grande puede mejorar ambigüedad, pero no corrige chunks defectuosos.

# %%
import matplotlib.pyplot as plt
models=["A","B","C"];recall=[.72,.84,.81];plt.bar(models,recall,color="#2a9d8f");plt.ylim(0,1);plt.title("Golden cases por modelo");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Cómo detectarías que un modelo confunde dos políticas parecidas?

# %% [markdown]
# ## Práctica guiada
#
# Creá golden cases y calculá éxito por modelo.

# %%
golden={"modelo_A":[1,0,1],"modelo_B":[1,1,1]};print({k:sum(v)/len(v) for k,v in golden.items()})

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Usar benchmarks ajenos al dominio como única evidencia.

# %% [markdown]
# ## Mini desafío
#
# E04 mide el costo temporal de esa elección.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
