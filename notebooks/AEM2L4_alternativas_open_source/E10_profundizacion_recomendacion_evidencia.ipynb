# %% [markdown]
# # Mini integrador: recomendación con evidencia
#
# **Tipo:** Profundización · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# Elegir y justificar

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, circuit breaker y shadow traffic.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# El cierre combina golden cases, costo, latencia, privacidad y operación. Una recomendación debe declarar límites y próximo experimento.

# %%
import matplotlib.pyplot as plt
steps=["router","cloud","local","fallback","métricas"]
plt.figure(figsize=(8,2));plt.plot(range(5),[0]*5,"o-",color="#1f4e79")
for i,s in enumerate(steps):plt.text(i,.1,s,ha="center")
plt.axis("off");plt.title("Arquitectura híbrida observable");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Cuándo usarías shadow traffic antes de migrar?

# %% [markdown]
# ## Práctica guiada
#
# Producí un reporte con recomendación, riesgos y métrica de éxito.

# %%
report={"recommendation":"híbrida","guardrail":"shadow traffic","success_metric":"Recall@5 >= 0.85"};print(report)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Desplegar un modelo nuevo sin medición ni fallback.

# %% [markdown]
# ## Mini desafío
#
# El proyecto integrador aplica estas decisiones al RAG FAQ.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
