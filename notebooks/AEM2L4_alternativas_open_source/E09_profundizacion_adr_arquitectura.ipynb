# %% [markdown]
# # ADR: decisión de arquitectura
#
# ## Problema real
#
# Registrar por qué, no solo qué

# %% [markdown]
# ## Conceptos clave
#
# Una ADR concisa explica contexto, alternativas, evidencia, decisión, consecuencias y fecha de revisión.

# %%
# Ejemplo ejecutable: ADR: decisión de arquitectura
import matplotlib.pyplot as plt
blocks=["contexto","alternativas","evidencia","decisión","revisión"]
plt.figure(figsize=(8,2));plt.plot(range(5),[0]*5,"o-",color="#6a4c93")
for i,b in enumerate(blocks):plt.text(i,.1,b,ha="center");plt.axis("off")
plt.title("ADR breve y auditable");plt.show()

# %% [markdown]
# ## Ejemplo ejecutable
#
# El bloque siguiente ilustra una implementación mínima del concepto.

# %%
# Ejemplo ejecutable: ADR: decisión de arquitectura
adr={"decision":"API administrada","because":"menor operación","review_when":"cambie volumen o privacidad"};print(adr)

# %% [markdown]
# ## Consideraciones técnicas
#
# Decisiones sin criterio de revisión; confundir preferencia con evidencia.
