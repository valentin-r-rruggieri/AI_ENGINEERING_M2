# %% [markdown]
# # Estimar costo y operación
#
# **Tipo:** Para resolver · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# El precio por token no es el costo total

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, decisiones cloud/local; lecture L4, costo.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# Una decisión responsable incorpora volumen, storage, red, hardware, mantenimiento y tiempo del equipo.

# %%
import matplotlib.pyplot as plt
items=["tokens","storage","hardware","operación"];values=[.2,.1,.4,.3];plt.pie(values,labels=items,autopct="%1.0f%%");plt.title("Costo total ilustrativo");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué cambia si el corpus se reindexa cada semana?

# %% [markdown]
# ## Práctica guiada
#
# Estimá un escenario de 100 mil chunks y documentá supuestos.

# %%
tokens=100_000;price=0.02;print("USD embeddings:",tokens/1_000_000*price)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Fijar precios en código o olvidar costos operativos.

# %% [markdown]
# ## Mini desafío
#
# E06 incorpora privacidad y soberanía.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
