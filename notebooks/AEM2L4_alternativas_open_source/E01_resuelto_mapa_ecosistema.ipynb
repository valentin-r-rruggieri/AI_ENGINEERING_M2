# %% [markdown]
# # Mapa del ecosistema de embeddings
#
# **Tipo:** Resuelto · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# No hay un proveedor universal

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, 'Servicios administrados vs Inferencia Local'.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# Servicios administrados y modelos locales resuelven el mismo problema con costos operativos y de privacidad distintos.

# %%
import matplotlib.pyplot as plt
plt.bar(["API","local"],[5,5],color=["#457b9d","#2a9d8f"]);plt.title("Dos caminos, responsabilidades distintas");plt.ylabel("criterios a evaluar");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué decisión depende del dato y cuál depende del volumen?

# %% [markdown]
# ## Práctica guiada
#
# Mapeá un caso de HR sensible sobre los dos caminos.

# %%
print({"api":"integración simple","local":"control y operación propia"})

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Elegir por popularidad y no por restricciones.

# %% [markdown]
# ## Mini desafío
#
# E02 descompone ambos flujos de inferencia.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
