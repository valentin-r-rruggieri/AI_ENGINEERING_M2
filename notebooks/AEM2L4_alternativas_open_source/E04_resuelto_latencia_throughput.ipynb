# %% [markdown]
# # Latencia y throughput
#
# **Tipo:** Resuelto · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# Una respuesta rápida no siempre escala

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, doble índice y benchmark local/cloud.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# p50, p95, tokens, batch y concurrencia ayudan a entender experiencia y capacidad. Medí la distribución, no solo un promedio.

# %%
import matplotlib.pyplot as plt
labels=["p50","p95","throughput"];values=[45,180,120];plt.bar(labels,values,color="#457b9d");plt.title("No mezclar unidades al interpretar rendimiento");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué métrica mirarías si un usuario ocasional ve demoras muy altas?

# %% [markdown]
# ## Práctica guiada
#
# Graficá p50/p95 y separá latencia de throughput.

# %%
latencies=[40,42,44,48,190];print({"p50":sorted(latencies)[2],"p95":190})

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Confundir solicitudes por segundo con latencia por solicitud.

# %% [markdown]
# ## Mini desafío
#
# E05 convierte consumo en una estimación de costo.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
