# %% [markdown]
# # Benchmark reproducible
#
# **Tipo:** Avanzado · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# La evidencia debe poder repetirse

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, doble índice benchmark local/cloud.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# El benchmark fija corpus, queries, métricas, hardware, versión de modelo y configuración. Sin ese registro no existe comparación defendible.

# %%
import matplotlib.pyplot as plt
runs=[1,2,3,4];plt.plot(runs,[.79,.81,.80,.82],"o-",label="Recall");plt.plot(runs,[7,6,8,7],"s-",label="p95 ms");plt.legend();plt.title("Repeticiones del benchmark");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué debe mantenerse fijo al comparar dos encoders?

# %% [markdown]
# ## Práctica guiada
#
# Armá un registro de experimento y agregá una observación.

# %%
experiment={"corpus":"v1","queries":"golden-v1","model":"candidate","recall_at_5":.81,"p95_ms":7};print(experiment)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Comparar una corrida aislada o esconder fallos.

# %% [markdown]
# ## Mini desafío
#
# E09 formaliza la decisión como ADR.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
