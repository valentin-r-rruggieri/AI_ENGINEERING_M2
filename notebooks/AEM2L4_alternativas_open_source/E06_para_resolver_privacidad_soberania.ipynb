# %% [markdown]
# # Privacidad y soberanía de datos
#
# **Tipo:** Para resolver · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# La arquitectura define dónde viaja la información

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, ventajas y desventajas cloud/local.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# PII, contratos y datos internos pueden exigir controles, retención y ejecución local. No es una propiedad que se agregue al final.

# %%
import matplotlib.pyplot as plt
plt.scatter([1,2,3],[3,2,1],s=[300,300,300],c=["#e76f51","#e9c46a","#2a9d8f"]);plt.text(1,3,"PII",ha="center");plt.text(2,2,"interno",ha="center");plt.text(3,1,"público",ha="center");plt.title("Clasificación de sensibilidad");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué campos del FAQ pueden salir del entorno y cuáles no?

# %% [markdown]
# ## Práctica guiada
#
# Construí una matriz de clasificación y decisión.

# %%
data=[{"field":"email","classification":"PII"},{"field":"política","classification":"interno"}];print(data)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Decir 'es privado' sin identificar el flujo de datos.

# %% [markdown]
# ## Mini desafío
#
# E07 une criterios en una matriz auditable.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
