# %% [markdown]
# # API administrada frente a inferencia local
#
# **Tipo:** Resuelto · **Lecture:** AEM2L4 — Alternativas y ecosistema open-source
#
# ## Problema real
#
# La arquitectura cambia aunque el vector se parezca

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L4, 'Flujo API administrada vs Inferencia local'.
#
# La visual se reconstruye como experimento modificable.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Identificar un trade-off real.
# - Medir una alternativa con el mismo dataset.
# - Registrar supuestos y límites.
# - Defender una recomendación revisable.

# %% [markdown]
# ## Modelo mental
#
# La API abstrae infraestructura; la ejecución local controla datos y operación. La calidad debe evaluarse con el mismo set de consultas.

# %%
import matplotlib.pyplot as plt
for y,label in enumerate(["app","API externa","vector"]):plt.text(y,0,label,ha="center",bbox={"boxstyle":"round","fc":"#dbe9f6"})
plt.plot([0,1,2],[0,0,0],"->");plt.xlim(-.5,2.5);plt.ylim(-1,1);plt.axis("off");plt.title("Flujo administrado");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué parte de la latencia no controlás al usar una API?

# %% [markdown]
# ## Práctica guiada
#
# Dibujá el trayecto del dato y marcá dónde aparece el riesgo de privacidad.

# %%
flow={"api":["app","red","proveedor"],"local":["app","CPU/GPU","modelo"]};print(flow)

# %% [markdown]
# ## Resultado esperado
#
# El resultado debe incluir datos, criterio y limitación. Una recomendación sin evidencia es solo una preferencia.

# %% [markdown]
# ## Errores frecuentes
#
# Comparar modelos con corpus distinto.

# %% [markdown]
# ## Mini desafío
#
# E03 define cómo comparar calidad semántica.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Registrá qué deberías medir antes de llevar la decisión a producción.
