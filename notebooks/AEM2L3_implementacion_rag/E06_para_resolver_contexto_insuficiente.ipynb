# %% [markdown]
# # Contexto insuficiente y abstención
#
# **Tipo:** Para resolver · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# No responder también puede ser correcto

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L3, Top-K vs Threshold; visual PI, política de abstención.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# Top-K siempre puede devolver chunks, pero esos chunks pueden ser irrelevantes. El sistema debe diferenciar 'hay resultados' de 'hay evidencia'.

# %%
import matplotlib.pyplot as plt
scores=[.91,.67,.42,.18]
plt.bar(range(4),scores,color=["#2a9d8f","#2a9d8f","#e9c46a","#e76f51"]);plt.axhline(.5,color="black",linestyle="--")
plt.title("Top-K no reemplaza un criterio de suficiencia");plt.xlabel("candidatos");plt.ylabel("score");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Top-K por sí solo puede garantizar grounding?

# %% [markdown]
# ## Práctica guiada
#
# Aplicá un threshold ilustrativo y devolvé una respuesta de abstención.

# %%
results=[{"id":"faq-1","score":.84},{"id":"faq-2","score":.31}]
sufficient=[r for r in results if r["score"]>=.5]
print("abstener" if not sufficient else sufficient)

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Forzar una respuesta por cada pregunta; calibrar threshold sin golden cases.

# %% [markdown]
# ## Mini desafío
#
# E07 arma el contexto trazable que verá el generador.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
