# %% [markdown]
# # Carga y normalización
#
# **Tipo:** Resuelto · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# La calidad empieza antes del embedding

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L3, 'Flujo de ingesta robusto — con validaciones'.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# Cargar, limpiar y validar protege al retrieval de páginas vacías, encabezados repetidos y codificación defectuosa.

# %%
import re, matplotlib.pyplot as plt
raw="  Encabezado repetido\n\nLa política de vacaciones requiere aprobación.   "
clean=re.sub(r"\s+"," ",raw).strip()
plt.figure(figsize=(8,2));plt.text(.02,.65,"antes: "+raw.replace("\n"," ↵ "),wrap=True);plt.text(.02,.2,"después: "+clean,wrap=True);plt.axis("off");plt.title("Normalización conserva significado");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué debe pasar si el documento queda vacío después de limpiarlo?

# %% [markdown]
# ## Práctica guiada
#
# Implementá una limpieza pequeña y conservá la fuente original.

# %%
def clean(text): return re.sub(r"\s+"," ",text).strip()
print(clean("  una\n política   clara "))

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Silenciar errores de lectura; eliminar estructura útil.

# %% [markdown]
# ## Mini desafío
#
# E03 persiste los documentos limpios en un vector store.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
