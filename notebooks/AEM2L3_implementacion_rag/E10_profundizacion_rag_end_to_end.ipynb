# %% [markdown]
# # Mini integrador: RAG end-to-end
#
# **Tipo:** Profundización · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# Del documento a una respuesta fundamentada

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L3, arquitectura productiva; presentación PI, blueprint RAG.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# El flujo completo coordina carga, chunks, embeddings, recuperación, contexto, generación, validación y observabilidad.

# %%
import matplotlib.pyplot as plt
steps=["cargar","indexar","recuperar","generar","validar","medir"]
plt.figure(figsize=(9,2));plt.plot(range(6),[0]*6,"o-",color="#1f4e79")
for i,s in enumerate(steps):plt.text(i,.1,s,ha="center")
plt.axis("off");plt.title("RAG end-to-end: responsabilidades visibles");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿En qué punto medirías latencia y dónde registrarías el error de un proveedor?

# %% [markdown]
# ## Práctica guiada
#
# Ejecutá el pipeline simulado y localizá la responsabilidad de cada función.

# %%
errors={"archivo_vacío":"detener","índice_ausente":"reindexar","sin_evidencia":"abstener"};print(errors)

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Estado global; errores silenciosos; mezclar responsabilidades.

# %% [markdown]
# ## Mini desafío
#
# L4 compara cómo cambia esta arquitectura entre API, modelos locales e híbridos.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
