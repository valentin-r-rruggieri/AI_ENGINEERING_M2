# %% [markdown]
# # Evaluar respuestas RAG
#
# **Tipo:** Profundización · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# Separar retrieval, grounding y redacción

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L3, diagnóstico de respuesta problemática; PI, evaluador bonus.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# Un sistema puede recuperar bien y contestar mal, o recuperar mal y redactar una respuesta convincente. La evaluación debe distinguir ambos fallos.

# %%
import matplotlib.pyplot as plt
metrics={"retrieval":.86,"grounding":.74,"claridad":.91}
plt.bar(metrics.keys(),metrics.values(),color="#457b9d");plt.ylim(0,1);plt.title("Rúbrica: dimensiones separadas");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué evidencia usarías para decidir si una afirmación está respaldada?

# %% [markdown]
# ## Práctica guiada
#
# Creá una rúbrica con relevancia, fidelidad y completitud.

# %%
rubric={"relevancia":8,"grounding":9,"completitud":7};print(sum(rubric.values())/len(rubric))

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Evaluar solo con una respuesta bonita; usar un juez sin ver los chunks.

# %% [markdown]
# ## Mini desafío
#
# E10 ensambla todas las etapas y sus fallos previsibles.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
