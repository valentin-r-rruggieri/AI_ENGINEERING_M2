# %% [markdown]
# # Chroma persistente
#
# **Tipo:** Resuelto · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# El índice necesita memoria entre ejecuciones

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Lecture L3, sección Chroma; Excalidraw L3, arquitectura productiva.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# Un vector store persistente guarda documentos, IDs, embeddings y metadata para que la consulta no dependa de reconstruir el corpus.

# %%
import matplotlib.pyplot as plt
records=[("faq-001","contraseña"),("faq-002","vacaciones"),("faq-003","licencias")]
plt.figure(figsize=(7,3))
for i,(identifier,label) in enumerate(records):
    plt.text(i,0,f"{identifier}\n{label}",ha="center",bbox={"boxstyle":"round","fc":"#d9ead3"})
plt.xlim(-.7,2.7);plt.ylim(-1,1);plt.axis("off");plt.title("Colección persistente: ID + documento + metadata");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Qué artefactos debés conservar junto al índice?

# %% [markdown]
# ## Práctica guiada
#
# Simulá la colección con registros y luego habilitá Chroma si está instalado.

# %%
collection={"ids":["faq-001"],"documents":["El enlace vence."],"metadatas":[{"source":"faq.txt"}]}
print(collection)

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Usar IDs aleatorios; no registrar modelo y configuración.

# %% [markdown]
# ## Mini desafío
#
# E04 transforma los chunks recuperados en un prompt grounded.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
