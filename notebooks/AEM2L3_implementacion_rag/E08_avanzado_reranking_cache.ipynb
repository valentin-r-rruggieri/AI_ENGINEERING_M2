# %% [markdown]
# # Reranking y caché
#
# **Tipo:** Avanzado · **Lecture:** AEM2L3 — Implementación de RAG
#
# ## Problema real
#
# Precisión y latencia en etapas separadas

# %% [markdown]
# ## Referencia visual y conceptual
#
# **Fuente de inspiración:** Excalidraw L3, reranking y tres capas de caché.
#
# La visual se recrea con código para experimentar los cambios de arquitectura.

# %% [markdown]
# ## Objetivos de aprendizaje
#
# - Explicar dónde vive cada responsabilidad del RAG.
# - Formular una predicción antes de ejecutar.
# - Producir evidencia trazable.
# - Distinguir fallos de retrieval, generación y validación.

# %% [markdown]
# ## Modelo mental
#
# El embedding recupera candidatos baratos; un reranker reordena pocos resultados. La caché evita trabajo repetido, pero debe invalidarse por versión de corpus.

# %%
import matplotlib.pyplot as plt
stages=["embedding","Top-20","reranker","Top-5","cache"]
plt.figure(figsize=(8,2));plt.plot(range(5),[0]*5,"o-",color="#6a4c93")
for i,s in enumerate(stages):plt.text(i,.1,s,ha="center")
plt.axis("off");plt.title("Precisión y latencia por etapas");plt.show()

# %% [markdown]
# ## Antes de ejecutar
#
# ¿Por qué el reranker no se ejecuta contra todo el corpus?

# %% [markdown]
# ## Práctica guiada
#
# Simulá reordenamiento y una clave de caché que incluya versión.

# %%
cache={};key=("¿vacaciones?","v1",4);cache[key]=["faq-7","faq-2"];print(cache)

# %% [markdown]
# ## Resultado esperado
#
# La práctica debe exponer entradas, salida y una condición verificable. Si hay una API configurada, integrala después de validar este flujo local.

# %% [markdown]
# ## Errores frecuentes
#
# Cachear respuestas sin versión; aplicar reranking a miles de documentos.

# %% [markdown]
# ## Mini desafío
#
# E09 convierte los resultados del pipeline en métricas de evaluación.

# %% [markdown]
# ## Cierre
#
# undefined
#
# Anotá qué métrica o validación usarías para demostrar que el cambio funciona.
